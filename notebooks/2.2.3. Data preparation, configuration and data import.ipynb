# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# Connection configuration
conexion = mysql.connector.connect(
  host="localhost",
  user="root",
  password="datapoet",
  database="dap1"
)

# Connection verification
if conexion.is_connected():
    print("Conexión exitosa a MySQL")
# Out:
# Conexión exitosa a MySQL

# %%
# !pip install ipython-sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 262.6 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 373.5 kB/s eta 0:00:00
# ...

# %% [markdown]
# #### 2.2.3.1 **World Bank Indicators**
#
# For the World Bank data, I first refined the list of relevant countries by excluding categories like regions and areas from the Excel file. I then imported this refined data into the **wb_countries** table in **Navicat**, resulting in a table with 216 records, each representing a country with its relevant information. This table served as a reference for comparing with other indicator tables imported separately. Subsequently, the data from the four separate indicator tables were consolidated into a single table, **wb_values**. SQL queries were used to verify and compare record counts across tables to ensure data consistency, and joins were performed to integrate the tables into the final data model.
#
# Here is an example of a join between wb_countries, with the refined list of countries, and wb_gdppc, the imported table for one of the indicators:

# %%
from sqlalchemy import create_engine
import pandas as pd

# Configure connection chain
engine = create_engine('mysql+pymysql://root:datapoet@localhost/dap1')

# Connect and execute query
query = '''SELECT c.country_code, g.country_code AS country_code_gdp
FROM wb_countries AS c
LEFT JOIN ____wb_gdppc AS g 
     ON c.country_code = g.country_code
WHERE g.country_code IS NULL;'''

df = pd.read_sql(query, engine)

# Show results
df.head()
# Out:
# Empty DataFrame
# Columns: [country_code, country_code_gdp]
# Index: []

# %% [markdown]
# Here, we see an example of a join between **wb_countries**, which contains the predefined list of countries, and **____wb_gdppc**, one of the imported indicator tables. By comparing the **country_code** from both tables using a LEFT JOIN, it is evident that there are no discrepancies between them. The country code serves as the common key for both tables. Subsequently, after verification, all four tables were merged into the parent table **wb_values** using the following query:

# %% [raw]
# INSERT INTO wb_values (
#   country_id,
#   indicator_id,
#   `1960`, `1961`, `1962`, `1963`, `1964`, `1965`, `1966`, `1967`, `1968`, `1969`,
#   `1970`, `1971`, `1972`, `1973`, `1974`, `1975`, `1976`, `1977`, `1978`, `1979`,
#   `1980`, `1981`, `1982`, `1983`, `1984`, `1985`, `1986`, `1987`, `1988`, `1989`,
#   `1990`, `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`,
#   `2000`, `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`,
#   `2010`, `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`,
#   `2020`, `2021`, `2022`, `2023`
# ) SELECT
#     wb_countries.id,
#     wb_indicators.id,
#     ____wb_gdppc.`1960`,
#     ____wb_gdppc.`1961`,
#     ____wb_gdppc.`1962`,
#     ____wb_gdppc.`1963`,
#     ____wb_gdppc.`1964`,
#     ____wb_gdppc.`1965`,
#     ____wb_gdppc.`1966`,
#     ____wb_gdppc.`1967`,
#     ____wb_gdppc.`1968`,
#     ____wb_gdppc.`1969`,
#     ____wb_gdppc.`1970`,
#     ____wb_gdppc.`1971`,
#     ____wb_gdppc.`1972`,
#     ____wb_gdppc.`1973`,
#     ____wb_gdppc.`1974`,
#     ____wb_gdppc.`1975`,
#     ____wb_gdppc.`1976`,
#     ____wb_gdppc.`1977`,
#     ____wb_gdppc.`1978`,
#     ____wb_gdppc.`1979`,
#     ____wb_gdppc.`1980`,
#     ____wb_gdppc.`1981`,
#     ____wb_gdppc.`1982`,
#     ____wb_gdppc.`1983`,
#     ____wb_gdppc.`1984`,
#     ____wb_gdppc.`1985`,
#     ____wb_gdppc.`1986`,
#     ____wb_gdppc.`1987`,
#     ____wb_gdppc.`1988`,
#     ____wb_gdppc.`1989`,
#     ____wb_gdppc.`1990`,
#     ____wb_gdppc.`1991`,
#     ____wb_gdppc.`1992`,
#     ____wb_gdppc.`1993`,
#     ____wb_gdppc.`1994`,
#     ____wb_gdppc.`1995`,
#     ____wb_gdppc.`1996`,
#     ____wb_gdppc.`1997`,
#     ____wb_gdppc.`1998`,
#     ____wb_gdppc.`1999`,
#     ____wb_gdppc.`2000`,
#     ____wb_gdppc.`2001`,
#     ____wb_gdppc.`2002`,
#     ____wb_gdppc.`2003`,
#     ____wb_gdppc.`2004`,
#     ____wb_gdppc.`2005`,
#     ____wb_gdppc.`2006`,
#     ____wb_gdppc.`2007`,
#     ____wb_gdppc.`2008`,
#     ____wb_gdppc.`2009`,
#     ____wb_gdppc.`2010`,
#     ____wb_gdppc.`2011`,
#     ____wb_gdppc.`2012`,
#     ____wb_gdppc.`2013`,
#     ____wb_gdppc.`2014`,
#     ____wb_gdppc.`2015`,
#     ____wb_gdppc.`2016`,
#     ____wb_gdppc.`2017`,
#     ____wb_gdppc.`2018`,
#     ____wb_gdppc.`2019`,
#     ____wb_gdppc.`2020`,
#     ____wb_gdppc.`2021`,
#     ____wb_gdppc.`2022`,
#     ____wb_gdppc.`2023`
# FROM
#   ____wb_gdppc
#   JOIN wb_countries ON ____wb_gdppc.country_code = wb_countries.country_code
#   JOIN wb_indicators ON ____wb_gdppc.indicator_code = wb_indicators.indicator_code;
#
# #INSERT INTO wb_values (
#   country_id,
#   indicator_id,
#   `1960`, `1961`, `1962`, `1963`, `1964`, `1965`, `1966`, `1967`, `1968`, `1969`,
#   `1970`, `1971`, `1972`, `1973`, `1974`, `1975`, `1976`, `1977`, `1978`, `1979`,
#   `1980`, `1981`, `1982`, `1983`, `1984`, `1985`, `1986`, `1987`, `1988`, `1989`,
#   `1990`, `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`,
#   `2000`, `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`,
#   `2010`, `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`,
#   `2020`, `2021`, `2022`, `2023`
# ) SELECT
#     wb_countries.id,
#     wb_indicators.id,
#     ____wb_netmigration.`1960`,
#     ____wb_netmigration.`1961`,
#     ____wb_netmigration.`1962`,
#     ____wb_netmigration.`1963`,
#     ____wb_netmigration.`1964`,
#     ____wb_netmigration.`1965`,
#   `2020`, `2021`, `2022`, `2023`
# ) SELECT
#     wb_countries.id,
#     wb_indicators.id,
#     ____wb_unemployment.`1960`,
#     ____wb_unemployment.`1961`,
#     ____wb_unemployment.`1962`,
#     ____wb_unemployment.`1963`,
#     ____wb_unemployment.`1964`,
#     ____wb_unemployment.`1965`,
#     ____wb_unemployment.`1966`,
#     ____wb_unemployment.`1967`,
#     ____wb_unemployment.`1968`,
#     ____wb_unemployment.`1969`,
#     ____wb_unemployment.`1970`,
#     ____wb_unemployment.`1971`,
#     ____wb_unemployment.`1972`,
#     ____wb_unemployment.`1973`,
#     ____wb_unemployment.`1974`,
#     ____wb_unemployment.`1975`,
#     ____wb_unemployment.`1976`,
#     ____wb_unemployment.`1977`,
#     ____wb_unemployment.`1978`,
#     ____wb_unemployment.`1979`,
#     ____wb_unemployment.`1980`,
#     ____wb_unemployment.`1981`,
#     ____wb_unemployment.`1982`,
#     ____wb_unemployment.`1983`,
#     ____wb_unemployment.`1984`,
#     ____wb_unemployment.`1985`,
#     ____wb_unemployment.`1986`,
#     ____wb_unemployment.`1987`,
#     ____wb_unemployment.`1988`,
#     ____wb_unemployment.`1989`,
#     ____wb_unemployment.`1990`,
#     ____wb_unemployment.`1991`,
#     ____wb_unemployment.`1992`,
#     ____wb_unemployment.`1993`,
#     ____wb_unemployment.`1994`,
#     ____wb_unemployment.`1995`,
#     ____wb_unemployment.`1996`,
#     ____wb_unemployment.`1997`,
#     ____wb_unemployment.`1998`,
#     ____wb_unemployment.`1999`,
#     ____wb_unemployment.`2000`,
#     ____wb_unemployment.`2001`,
#     ____wb_unemployment.`2002`,
#     ____wb_unemployment.`2003`,
#     ____wb_unemployment.`2004`,
#     ____wb_unemployment.`2005`,
#     ____wb_unemployment.`2006`,
#     ____wb_unemployment.`2007`,
#     ____wb_unemployment.`2008`,
#     ____wb_unemployment.`2009`,
#     ____wb_unemployment.`2010`,
#     ____wb_unemployment.`2011`,
#     ____wb_unemployment.`2012`,
#     ____wb_unemployment.`2013`,
#     ____wb_unemployment.`2014`,
#     ____wb_unemployment.`2015`,
#     ____wb_unemployment.`2016`,
#     ____wb_unemployment.`2017`,
#     ____wb_unemployment.`2018`,
#     ____wb_unemployment.`2019`,
#     ____wb_unemployment.`2020`,
#     ____wb_unemployment.`2021`,
#     ____wb_unemployment.`2022`,
#     ____wb_unemployment.`2023`
# FROM
#   ____wb_unemployment
#   JOIN wb_countries ON ____wb_unemployment.country_code = wb_countries.country_code
#   JOIN wb_indicators ON ____wb_unemployment.indicator_code = wb_indicators.indicator_code;

# %% [markdown]
# We can check on the three tables conforming the **wb_indicators_schema** (first 15 records):

# %%
# !pip install qgrid
# Out:
# ...
#      ---------------------------------------- 0.0/889.2 kB ? eta -:--:--
#      ---------------------------------------- 10.2/889.2 kB ? eta -:--:--
#       ------------------------------------ 20.5/889.2 kB 217.9 kB/s eta 0:00:04
#      -- ---------------------------------- 61.4/889.2 kB 409.6 kB/s eta 0:00:03
#      ----- ------------------------------ 143.4/889.2 kB 774.0 kB/s eta 0:00:01
#      ------------------ ------------------- 440.3/889.2 kB 2.1 MB/s eta 0:00:01
#      --------------------------------- ---- 778.2/889.2 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 889.2/889.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761261 sha256=5e09de5a5af2721856b6cd5210f8b3aaa89075e3ff59a196a0a3cad2df88baf5
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd
from IPython.display import display, HTML

# Configure the connection string
engine = create_engine('mysql+pymysql://root:datapoet@localhost/dap1')

# Query and display the wb_countries table
query_countries = '''
SELECT * FROM wb_countries
LIMIT 15;
'''
df_countries = pd.read_sql(query_countries, engine)

# Display the DataFrame as an HTML table
print("wb_countries Table:")
display(HTML(df_countries.to_html()))

# Query and display the wb_values table
query_values = '''
SELECT * FROM wb_values
LIMIT 15;
'''
df_values = pd.read_sql(query_values, engine)

# Display the DataFrame as an HTML table
print("wb_values Table:")
display(HTML(df_values.to_html()))

# Query and display the wb_indicators table
query_indicators = '''
SELECT * FROM wb_indicators
LIMIT 15;
'''
df_indicators = pd.read_sql(query_indicators, engine)

# Display the DataFrame as an HTML table
print("wb_indicators Table:")
display(HTML(df_indicators.to_html()))
# Out:
# wb_countries Table:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>country_code</th>
#       <th>country_name</th>
#       <th>region</th>
#       <th>income_group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>ABW</td>
#       <td>Aruba</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>High income</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>AFG</td>
#       <td>Afghanistan</td>
#       <td>South Asia</td>
#       <td>Low income</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>AGO</td>
#       <td>Angola</td>
#       <td>Sub-Saharan Africa</td>
#       <td>Lower middle income</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>ALB</td>
#       <td>Albania</td>
#       <td>Europe &amp; Central Asia</td>
# ...

# %% [markdown]
# #### 2.2.3.2 **United Nations: Population Division**
#
# For the United Nations data, SQL queries were used to verify and ensure data consistency, integrate the tables into the final data model.

# %%
from sqlalchemy import create_engine
import pandas as pd
from IPython.display import display, HTML

# Configure the connection string
engine = create_engine('mysql+pymysql://root:datapoet@localhost/dap1')

# Query and display the wb_countries table
query_countries = '''
SELECT * FROM un_locations
LIMIT 25;
'''
df_countries = pd.read_sql(query_countries, engine)

# Display the DataFrame as an HTML table
print("un_locations Table:")
display(HTML(df_countries.to_html()))

# Query and display the wb_values table
query_values = '''
SELECT * FROM un_migration_stock
LIMIT 25;
'''
df_values = pd.read_sql(query_values, engine)

# Display the DataFrame as an HTML table
print("un_migration_stock Table:")
display(HTML(df_values.to_html()))
# Out:
# un_locations Table:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>country_code</th>
#       <th>location_type</th>
#       <th>geographic_subregion</th>
#       <th>geographic_region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>Afghanistan</td>
#       <td>AFG</td>
#       <td>Country</td>
#       <td>Southern Asia</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8</td>
#       <td>Albania</td>
#       <td>ALB</td>
#       <td>Country</td>
#       <td>Southern Europe</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>Algeria</td>
#       <td>DZA</td>
#       <td>Country</td>
#       <td>Northern Africa</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16</td>
#       <td>American Samoa*</td>
# ...
