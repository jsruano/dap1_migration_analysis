# %%
pip install ipython-sql mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:datapoet@localhost/dap1

# %% [markdown]
# The data cleaning process in **un_countries** involved the following queries, creating a new view called **un_countries_v**:

# %% [raw]
# WITH un_countries_cleaning1 AS (
# SELECT
#   id,
#   TRIM(BOTH '*' FROM name) AS name,
#   TRIM(BOTH '*' FROM country_code) AS country_code,
#   subregion
# FROM un_countries
# ),
#
# un_countries_cleaning2 AS (
# SELECT
#   id,
#   REPLACE(REPLACE(REPLACE(TRIM(name), '\n', ''), '\r', ''), '\t', '') AS name,
#   REPLACE(REPLACE(REPLACE(TRIM(country_code), '\n', ''), '\r', ''), '\t', '') AS country_code,
#   subregion
# FROM un_countries_cleaning1
# )
#
# SELECT
#   id,
#   name,
#   country_code,
#   subregion
# FROM un_countries_cleaning2;

# %%
# %%sql
# SELECT * FROM un_countries_v;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 235 rows affected.
# [(4, 'Afghanistan', 'AFG', 5501),
#  (8, 'Albania', 'ALB', 925),
#  (12, 'Algeria', 'DZA', 912),
#  (16, 'American Samoa', 'ASM', 957),
#  (20, 'Andorra', 'AND', 925),
#  (24, 'Angola', 'AGO', 911),
#  (28, 'Antigua and Barbuda', 'ATG', 915),
#  (31, 'Azerbaijan', 'AZE', 922),
#  (32, 'Argentina', 'ARG', 931),
#  (36, 'Australia', 'AUS', 927),
#  (40, 'Austria', 'AUT', 926),
#  (44, 'Bahamas', 'BHS', 915),
#  (48, 'Bahrain', 'BHR', 922),
#  (50, 'Bangladesh', 'BGD', 5501),
#  (51, 'Armenia', 'ARM', 922),
#  (52, 'Barbados', 'BRB', 915),
#  (56, 'Belgium', 'BEL', 926),
#  (60, 'Bermuda', 'BMU', 999),
#  (64, 'Bhutan', 'BTN', 5501),
#  (68, 'Bolivia (Plurinational State of)', 'BOL', 931),
#  (70, 'Bosnia and Herzegovina', 'BIH', 925),
#  (72, 'Botswana', 'BWA', 913),
#  (76, 'Brazil', 'BRA', 931),
#  (84, 'Belize', 'BLZ', 916),
#  (90, 'Solomon Islands', 'SLB', 928),
#  (92, 'British Virgin Islands', 'VGB', 915),
# ...

# %% [markdown]
# The data cleaning process in **wb_regions** consisted of this verification, before updating the values in the table:

# %%
# %%sql
# SELECT
#   id,
#   REPLACE (name, ' & ', ' and ') AS region
# FROM wb_regions;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 7 rows affected.
# [(1, 'Latin America andCaribbean'),
#  (2, 'South Asia'),
#  (3, 'Sub-Saharan Africa'),
#  (4, 'Europe andCentral Asia'),
#  (5, 'Middle East andNorth Africa'),
#  (6, 'East Asia andPacific'),
#  (7, 'North America')]

# %% [raw]
# UPDATE wb_regions
# SET name = REPLACE(name, ' & ', ' and');
