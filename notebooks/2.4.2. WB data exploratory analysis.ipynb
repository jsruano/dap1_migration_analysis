# %%
pip install ipython-sql mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:datapoet@localhost/dap1

# %% [markdown]
# #### 2.4.1 **World Bank: Indicators**
#
# In the data exploration phase, several **potentially relevant indicators** from the World Bank were selected for analysis. The initial focus was on constructing visualizations in **Power BI** to assess which indicators were sufficiently consistent to include in the exploratory analysis.
#
# The four indicators are:
#
# - GDP per capita (current US$)
# - Net migration
# - Poverty headcount ratio at national poverty lines (% of population)
# - Unemployment, total (% of total labor force) (modeled ILO estimate)
#
# Before importing the data into Power BI, the table **wb_values** was unpivoted using the query:

# %% [raw]
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1960' AS year,
#     `1960` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1961' AS year,
#     `1961` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1962' AS year,
#     `1962` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1963' AS year,
#     `1963` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1964' AS year,
#     `1964` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1965' AS year,
#     `1965` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1966' AS year,
#     `1966` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1967' AS year,
#     `1967` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1968' AS year,
#     `1968` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1969' AS year,
#     `1969` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1970' AS year,
#     `1970` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1971' AS year,
#     `1971` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1972' AS year,
#     `1972` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1973' AS year,
#     `1973` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1974' AS year,
#     `1974` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1975' AS year,
#     `1975` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1976' AS year,
#     `1976` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1977' AS year,
#     `1977` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1978' AS year,
#     `1978` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1979' AS year,
#     `1979` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1980' AS year,
#     `1980` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1981' AS year,
#     `1981` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1982' AS year,
#     `1982` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1983' AS year,
#     `1983` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1984' AS year,
#     `1984` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1985' AS year,
#     `1985` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1986' AS year,
#     `1986` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1987' AS year,
#     `1987` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1988' AS year,
#     `1988` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1989' AS year,
#     `1989` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1990' AS year,
#     `1990` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1991' AS year,
#     `1991` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1992' AS year,
#     `1992` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1993' AS year,
#     `1993` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1994' AS year,
#     `1994` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1995' AS year,
#     `1995` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1996' AS year,
#     `1996` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1997' AS year,
#     `1997` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1998' AS year,
#     `1998` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '1999' AS year,
#     `1999` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2000' AS year,
#     `2000` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2001' AS year,
#     `2001` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2002' AS year,
#     `2002` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2003' AS year,
#     `2003` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2004' AS year,
#     `2004` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2005' AS year,
#     `2005` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2006' AS year,
#     `2006` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2007' AS year,
#     `2007` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2008' AS year,
#     `2008` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2009' AS year,
#     `2009` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2010' AS year,
#     `2010` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2011' AS year,
#     `2011` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2012' AS year,
#     `2012` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2013' AS year,
#     `2013` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2014' AS year,
#     `2014` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2015' AS year,
#     `2015` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2016' AS year,
#     `2016` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2017' AS year,
#     `2017` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2018' AS year,
#     `2018` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2019' AS year,
#     `2019` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2020' AS year,
#     `2020` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2021' AS year,
#     `2021` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2022' AS year,
#     `2022` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id
#
# UNION ALL
#
# SELECT
#     i.id AS indicator_id,
#     i.name AS indicator_name,
#     c.id AS country_id,
#     c.name AS country_name,
#     '2023' AS year,
#     `2023` AS value
# FROM
#     wb_values AS v
# JOIN
#     wb_countries AS c ON v.country_id = c.id
# JOIN
#     wb_indicators AS i ON v.indicator_id = i.id;

# %% [markdown]
# ⬇️ **wb_values_v_unpivoted**

# %%
# %%sql
# SELECT * FROM wb_values_v_unpivoted LIMIT 200;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 200 rows affected.
# [(1, 'GDP per capita (current US$)', 1, 'Aruba', '1960', None),
#  (1, 'GDP per capita (current US$)', 2, 'Afghanistan', '1960', None),
#  (1, 'GDP per capita (current US$)', 3, 'Angola', '1960', None),
#  (1, 'GDP per capita (current US$)', 4, 'Albania', '1960', None),
#  (1, 'GDP per capita (current US$)', 5, 'Andorra', '1960', None),
#  (1, 'GDP per capita (current US$)', 6, 'United Arab Emirates', '1960', None),
#  (1, 'GDP per capita (current US$)', 7, 'Argentina', '1960', None),
#  (1, 'GDP per capita (current US$)', 8, 'Armenia', '1960', None),
#  (1, 'GDP per capita (current US$)', 9, 'American Samoa', '1960', None),
#  (1, 'GDP per capita (current US$)', 10, 'Antigua and Barbuda', '1960', None),
#  (1, 'GDP per capita (current US$)', 11, 'Australia', '1960', 1810.59744278609),
#  (1, 'GDP per capita (current US$)', 12, 'Austria', '1960', 943.610800103121),
# ...

# %% [markdown]
# The **wb_values_v_unpivoted** view was better suited for manipulation and analysis in Power BI.
#
# Upon reviewing the visualizations, the **poverty headcount ratio** indicator was excluded from further analysis due to the lack of consistent data across countries. While relevant for analyzing national poverty, the inconsistency in available data limited its comparability between countries.
#
# Subsequently, trend lines were examined across the different indicators, followed by a study of correlations between countries and indicators to derive potentially insightful relationships.

# %% [markdown]
# #### Correlation between **Argentina's net migration** and **Argentina's unemployment rate**
# World Bank Indicators/ 1991-2023

# %%
# %%sql
# SELECT
#     (
#         (COUNT(*) * SUM(arg_mig.value * arg_unemp.value)) - (SUM(arg_mig.value) * SUM(arg_unemp.value))
#     ) /
#     SQRT(
#         (COUNT(*) * SUM(POW(arg_mig.value, 2)) - POW(SUM(arg_mig.value), 2)) *
#         (COUNT(*) * SUM(POW(arg_unemp.value, 2)) - POW(SUM(arg_unemp.value), 2))
#     ) AS correlation
# FROM
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Net migration' AND year > 1990) arg_mig
# JOIN
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) arg_unemp
# ON arg_mig.year = arg_unemp.year;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 1 rows affected.
# [(-0.7212184223819235,)]

# %% [markdown]
# #### Correlation between **Argentina's net migration** and **Spain's unemployment rate**
# World Bank Indicators/ 1991-2023

# %%
# %%sql
# SELECT
#     (
#         (COUNT(*) * SUM(arg_mig.value * sp_unemp.value)) - (SUM(arg_mig.value) * SUM(sp_unemp.value))
#     ) /
#     SQRT(
#         (COUNT(*) * SUM(POW(arg_mig.value, 2)) - POW(SUM(arg_mig.value), 2)) *
#         (COUNT(*) * SUM(POW(sp_unemp.value, 2)) - POW(SUM(sp_unemp.value), 2))
#     ) AS correlation
# FROM
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Net migration' AND year > 1990) arg_mig
# JOIN
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Spain' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) sp_unemp
# ON arg_mig.year = sp_unemp.year;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 1 rows affected.
# [(0.3423962431300349,)]

# %% [markdown]
# #### Correlation between **Argentina's net migration** and **Spain's unemployment rate**
# World Bank Indicators/ 1991-2023

# %%
# %%sql
# SELECT
#     (
#         (COUNT(*) * SUM(arg_mig.value * it_unemp.value)) - (SUM(arg_mig.value) * SUM(it_unemp.value))
#     ) /
#     SQRT(
#         (COUNT(*) * SUM(POW(arg_mig.value, 2)) - POW(SUM(arg_mig.value), 2)) *
#         (COUNT(*) * SUM(POW(it_unemp.value, 2)) - POW(SUM(it_unemp.value), 2))
#     ) AS correlation
# FROM
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Net migration' AND year > 1990) arg_mig
# JOIN
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Italy' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) it_unemp
# ON arg_mig.year = it_unemp.year;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 1 rows affected.
# [(0.15511478083269578,)]

# %% [markdown]
# #### Correlation between **Spain's unemployment rate** and **Italy's unemployment rate**
# World Bank Indicators/ 1991-2023

# %%
# %%sql
# SELECT
#     (
#         (COUNT(*) * SUM(arg_unemp.value * sp_unemp.value)) - (SUM(arg_unemp.value) * SUM(sp_unemp.value))
#     ) /
#     SQRT(
#         (COUNT(*) * SUM(POW(arg_unemp.value, 2)) - POW(SUM(arg_unemp.value), 2)) *
#         (COUNT(*) * SUM(POW(sp_unemp.value, 2)) - POW(SUM(sp_unemp.value), 2))
#     ) AS correlation
# FROM
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) arg_unemp
# JOIN
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Spain' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) sp_unemp
# ON arg_unemp.year = sp_unemp.year;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 1 rows affected.
# [(-0.16260482826243824,)]

# %% [markdown]
# #### Correlation between **Argentina's unemployment rate** and **Italy's unemployment rate**
# World Bank Indicators/ 1991-2023

# %%
# %%sql
# SELECT
#     (
#         (COUNT(*) * SUM(arg_unemp.value * it_unemp.value)) - (SUM(arg_unemp.value) * SUM(it_unemp.value))
#     ) /
#     SQRT(
#         (COUNT(*) * SUM(POW(arg_unemp.value, 2)) - POW(SUM(arg_unemp.value), 2)) *
#         (COUNT(*) * SUM(POW(it_unemp.value, 2)) - POW(SUM(it_unemp.value), 2))
#     ) AS correlation
# FROM
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Argentina' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) arg_unemp
# JOIN
#     (SELECT year, value FROM wb_values_v_unpivoted WHERE country_name = 'Italy' AND indicator_name = 'Unemployment, total (% of total labor force) (modeled ILO estimate)' AND year > 1990) it_unemp
# ON arg_unemp.year = it_unemp.year;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 1 rows affected.
# [(0.2065892633840354,)]

# %% [markdown]
# The correlation values between the selected indicators were generally weak, ranging between 0 and 0.3, indicating a **lack of strong relationships**. One notable exception was the correlation between Argentina's Net Migration and Argentina's Unemployment, which showed a value of -0.72, though this still **does not reflect a robust correlation**. These results suggest that these variables are not directly related within the scope of our dataset, aligning with the understanding that such phenomena are typically influenced by multiple factors.
