# %%
pip install ipython-sql mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:datapoet@localhost/dap1

# %% [markdown]
# The data cleaning process in **wb_countries** involved the following queries, creating a new view called **un_locations_view1**. Through this query:
# *SELECT id, name FROM un_locations WHERE BINARY name = UPPER(name)* only the uppercase names are obtained in order to transform them:

# %% [raw]
# WITH un_locations_cleaning1 AS (
# SELECT
#   id,
#   TRIM(BOTH '*' FROM name) AS name,
#   TRIM(BOTH '*' FROM country_code) AS country_code,
#   location_type,
#   geographic_subregion,
#   geographic_region
# FROM un_locations
# ),
#
# un_locations_cleaning2 AS (
# SELECT
#   id,
#   REPLACE(REPLACE(REPLACE(TRIM(name), '\n', ''), '\r', ''), '\t', '') AS name,
#   REPLACE(REPLACE(REPLACE(TRIM(country_code), '\n', ''), '\r', ''), '\t', '') AS country_code,
#   REPLACE(REPLACE(REPLACE(TRIM(location_type), '\n', ''), '\r', ''), '\t', '') AS location_type,
#   REPLACE(REPLACE(REPLACE(TRIM(geographic_subregion), '\n', ''), '\r', ''), '\t', '') AS geographic_subregion,
#   REPLACE(REPLACE(REPLACE(TRIM(geographic_region), '\n', ''), '\r', ''), '\t', '') AS geographic_region
# FROM un_locations_cleaning1
# ),
#
# -- Through this query: SELECT id, name FROM un_locations WHERE BINARY name = UPPER(name) only the uppercase names are obtained in order to transform them in the following code:
#
# un_locations_cleaning3 AS (
# SELECT
#   id,
#   CASE
#     WHEN name = 'WORLD' THEN 'World'
#     WHEN name = 'AFRICA' THEN 'Africa'
#     WHEN name = 'LATIN AMERICA AND THE CARIBBEAN' THEN 'Latin America and the Caribbean'
#     WHEN name = 'NORTHERN AMERICA' THEN 'Northern America'
#     WHEN name = 'EUROPE' THEN 'Europe'
#     WHEN name = 'OCEANIA' THEN 'Oceania'
#     WHEN name = 'ASIA' THEN 'Asia'
#   ELSE name
#   END AS name,
#   country_code,
#   CASE
#     WHEN location_type = 'WORLD' THEN 'World'
#     WHEN location_type = 'AFRICA' THEN 'Africa'
#     WHEN location_type = 'LATIN AMERICA AND THE CARIBBEAN' THEN 'Latin America and the Caribbean'
#     WHEN location_type = 'NORTHERN AMERICA' THEN 'Northern America'
#     WHEN location_type = 'EUROPE' THEN 'Europe'
#     WHEN location_type = 'OCEANIA' THEN 'Oceania'
#     WHEN location_type = 'ASIA' THEN 'Asia'
#   ELSE location_type
#   END AS location_type,
#   CASE
#     WHEN geographic_subregion = 'WORLD' THEN 'World'
#     WHEN geographic_subregion = 'AFRICA' THEN 'Africa'
#     WHEN geographic_subregion = 'LATIN AMERICA AND THE CARIBBEAN' THEN 'Latin America and the Caribbean'
#     WHEN geographic_subregion = 'NORTHERN AMERICA' THEN 'Northern America'
#     WHEN geographic_subregion = 'EUROPE' THEN 'Europe'
#     WHEN geographic_subregion = 'OCEANIA' THEN 'Oceania'
#     WHEN geographic_subregion = 'ASIA' THEN 'Asia'
#   ELSE geographic_subregion
#   END AS geographic_subregion,
#   CASE
#     WHEN geographic_region = 'WORLD' THEN 'World'
#     WHEN geographic_region = 'AFRICA' THEN 'Africa'
#     WHEN geographic_region = 'LATIN AMERICA AND THE CARIBBEAN' THEN 'Latin America and the Caribbean'
#     WHEN geographic_region = 'NORTHERN AMERICA' THEN 'Northern America'
#     WHEN geographic_region = 'EUROPE' THEN 'Europe'
#     WHEN geographic_region = 'OCEANIA' THEN 'Oceania'
#     WHEN geographic_region = 'ASIA' THEN 'Asia'
#   ELSE geographic_region
#   END AS geographic_region
# FROM un_locations_cleaning2
# )
#
# SELECT
#   id,
#   REPLACE (name, 'And', 'and') AS name,
#   NULLIF(country_code, '') AS country_code,
#   REPLACE (location_type, 'And', 'and') AS location_type,
#   REPLACE (geographic_subregion, 'And', 'and') AS geographic_subregion,
#   REPLACE (geographic_region, 'And', 'and') AS geographic_region
# FROM un_locations_cleaning3;

# %%
# %%sql
# SELECT * FROM un_locations_view1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 283 rows affected.
# [(4, 'Afghanistan', 'AFG', 'Country', 'Southern Asia', 'Asia'),
#  (8, 'Albania', 'ALB', 'Country', 'Southern Europe', 'Europe'),
#  (12, 'Algeria', 'DZA', 'Country', 'Northern Africa', 'Africa'),
#  (16, 'American Samoa', 'ASM', 'Country', 'Polynesia', 'Oceania'),
#  (20, 'andorra', 'AND', 'Country', 'Southern Europe', 'Europe'),
#  (24, 'Angola', 'AGO', 'Country', 'Middle Africa', 'Africa'),
#  (28, 'Antigua and Barbuda', 'ATG', 'Country', 'Caribbean', 'Latin America and the Caribbean'),
#  (31, 'Azerbaijan', 'AZE', 'Country', 'Western Asia', 'Asia'),
#  (32, 'Argentina', 'ARG', 'Country', 'South America', 'Latin America and the Caribbean'),
#  (36, 'Australia', 'AUS', 'Country', 'Australia and New Zealand', 'Oceania'),
#  (40, 'Austria', 'AUT', 'Country', 'Western Europe', 'Europe'),
#  (44, 'Bahamas', 'BHS', 'Country', 'Caribbean', 'Latin America and the Caribbean'),
# ...

# %% [markdown]
# The data cleaning process in **un_locations** consisted of:

# %%
# %%sql
# SELECT
#   id,
#   country_code,
#   country_name,
#   REPLACE (region, '&', 'and') AS region,
#   income_group
# FROM wb_countries;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 216 rows affected.
# [(1, 'ABW', 'Aruba', 'Latin America and Caribbean', 'High income'),
#  (2, 'AFG', 'Afghanistan', 'South Asia', 'Low income'),
#  (3, 'AGO', 'Angola', 'Sub-Saharan Africa', 'Lower middle income'),
#  (4, 'ALB', 'Albania', 'Europe and Central Asia', 'Upper middle income'),
#  (5, 'AND', 'Andorra', 'Europe and Central Asia', 'High income'),
#  (6, 'ARE', 'United Arab Emirates', 'Middle East and North Africa', 'High income'),
#  (7, 'ARG', 'Argentina', 'Latin America and Caribbean', 'Upper middle income'),
#  (8, 'ARM', 'Armenia', 'Europe and Central Asia', 'Upper middle income'),
#  (9, 'ASM', 'American Samoa', 'East Asia and Pacific', 'High income'),
#  (10, 'ATG', 'Antigua and Barbuda', 'Latin America and Caribbean', 'High income'),
#  (11, 'AUS', 'Australia', 'East Asia and Pacific', 'High income'),
#  (12, 'AUT', 'Austria', 'Europe and Central Asia', 'High income'),
# ...
