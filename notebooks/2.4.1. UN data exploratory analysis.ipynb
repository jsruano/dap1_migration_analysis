# %%
pip install ipython-sql mysql-connector-python
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ruano\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: mysql-connector-python in c:\users\ruano\anaconda3\lib\site-packages (9.0.0)
# Requirement already satisfied: prettytable in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (3.11.0)
# Requirement already satisfied: ipython in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (8.25.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (2.0.30)
# Requirement already satisfied: sqlparse in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (0.5.1)
# Requirement already satisfied: six in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\ruano\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ruano\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ruano\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ruano\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ruano\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ruano\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\ruano\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ruano\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ruano\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:datapoet@localhost/dap1

# %% [markdown]
# #### 2.4.1 **United Nations: Population Division**
#
# In the initial phase of exploratory analysis, the focus was on understanding **global migration dynamics** through migration stock data. Specific queries provided key insights into migration trends at a worldwide level, thus providing crucial context for the project. Other queries focused on **specific interregional** migration phenomena, such as those that explain the **relationship between South America and Europe**, which allowed a more granular understanding of transcontinental movements and their impact on both regions.

# %% [markdown]
# **Migration stock from Latin American countries to the rest of the world**
#
# The query results are sorted by migration stock values from highest to lowest. The highest migration stocks occur within the Americas, predominantly from Central America and South America to the United States. European migration stocks appear later, with the first instance at the 13th position, where migration from South America (Colombia) to Spain is recorded. This highlights the prominence of inter-American migration over transcontinental flows, particularly toward Europe.

# %%
# %%sql
# SELECT
#   ROW_NUMBER() OVER (ORDER BY men_women_2020 DESC) AS row_num,
#   c1.id AS origin_id,
#   c1.name AS origin_name,
#   s1.name AS origin_subregion,
#   r1.name AS origin_region,
#   c2.id AS destination_id,
#   c2.name AS destination_name,
#   s2.name AS destination_subregion,
#   r2.name AS destination_region,
#   men_women_1990,
#   men_women_1995,
#   men_women_2000,
#   men_women_2005,
#   men_women_2010,
#   men_women_2015,
#   men_women_2020
# FROM
#   un_migration_stock AS m
#   JOIN un_countries_v AS c1 ON m.origin = c1.id
#   JOIN un_countries_v AS c2 ON m.destination = c2.id
#   JOIN un_subregions AS s1 ON c1.subregion = s1.id
#   JOIN un_subregions AS s2 ON c2.subregion = s2.id
#   JOIN un_regions AS r1 ON s1.region = r1.id
#   JOIN un_regions AS r2 ON s2.region = r2.id
# WHERE
#   origin IN (
#     SELECT id
#     FROM un_countries_v
#     WHERE subregion IN (931, 916, 915)
#     )
#   AND
#   destination NOT IN (
#     SELECT id
#     FROM un_countries_v
#     WHERE subregion IN (931, 916, 915)
#     )
# ORDER BY
#   men_women_2020 DESC
# LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
#
 'South America', 'Latin America and the Caribbean', 840, 'United States of America', 'Northern America', 'Northern America', 2860, 4274, 5720, 9938, 14573, 14794, 21498),
#  (93, 32, 'Argentina', 'South America', 'Latin America and the Caribbean', 124, 'Canada', 'Northern America', 'Northern America', 10660, 12036, 13698, 15923, 18870, 19310, 20921),
#  (94, 604, 'Peru', 'South America', 'Latin America and the Caribbean', 276, 'Germany', 'Western Europe', 'Europe', 4288, 6123, 7957, 11825, 14955, 15349, 20599),
#  (95, 32, 'Argentina', 'South America', 'Latin America and the Caribbean', 276, 'Germany', 'Western Europe', 'Europe', 4499, 4616, 4732, 10339, 14929, 15323, 20566),
#  (96, 484, 'Mexico', 'Central America', 'Latin America and the Caribbean', 276, 'Germany', 'Western Europe', 'Europe', 3437, 4652, 5867, 10738, 14713, 15100, 20266),
#  (97, 192, 'Cuba', 'Caribbean', 'Latin America and the Caribbean', 124, 'Canada', 'Northern America', 'Northern America', 1737, 3462, 5269, 9129, 13340, 17740, 19221),
#  (98, 320, 'Guatemala', 'Central America', 'Latin America and the Caribbean', 124, 'Canada', 'Northern America', 'Northern America', 8559, 11127, 13960, 14401, 15285, 17169, 18602),
#  (99, 32, 'Argentina', 'South America', 'Latin America and the Caribbean', 36, 'Australia', 'Australia and New Zealand', 'Oceania', 13155, 12541, 12020, 13088, 13730, 15510, 17900),
#  (100, 152, 'Chile', 'South America', 'Latin America and the Caribbean', 276, 'Germany', 'Western Europe', 'Europe', 6888, 6584, 6279, 9900, 12839, 13178, 17686)]

# %% [markdown]
# Several **aggregation functions** were employed in the queries for data exploration, revealing the total migration stock from various regions of the world to Europe, providing interesting insights.

# %% [markdown]
# **Migration stock from world regions to Europe**

# %%
# %%sql
# SELECT
#   ROW_NUMBER() OVER (ORDER BY SUM(men_women_2020) DESC) AS ranking,
#   origin_region,
#   destination_region,
#   SUM(men_women_1990) AS region_tot_1990,
#   SUM(men_women_1995) AS region_tot_1995,
#   SUM(men_women_2000) AS region_tot_2000,
#   SUM(men_women_2005) AS region_tot_2005,
#   SUM(men_women_2010) AS region_tot_2010,
#   SUM(men_women_2015) AS region_tot_2015,
#   SUM(men_women_2020) AS region_tot_2020
# FROM
#   wcountries_to_wcountries_inter_region_v
# WHERE
#   destination_region = 'Europe'
# GROUP BY
#   origin_region,
#   destination_region
# ORDER BY
#   region_tot_2020 DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 5 rows affected.
# [(1, 'Asia', 'Europe', Decimal('13453956'), Decimal('14667430'), Decimal('15541563'), Decimal('16825888'), Decimal('18287405'), Decimal('19797557'), Decimal('23203976')),
#  (2, 'Africa', 'Europe', Decimal('4682594'), Decimal('5179831'), Decimal('5797189'), Decimal('7620545'), Decimal('8748280'), Decimal('9536606'), Decimal('11024274')),
#  (3, 'Latin America and the Caribbean', 'Europe', Decimal('1104536'), Decimal('1340812'), Decimal('1699981'), Decimal('3453004'), Decimal('4581301'), Decimal('4487571'), Decimal('5395924')),
#  (4, 'Northern America', 'Europe', Decimal('769469'), Decimal('743008'), Decimal('735943'), Decimal('824591'), Decimal('921685'), Decimal('972405'), Decimal('1100304')),
#  (5, 'Oceania', 'Europe', Decimal('191405'), Decimal('222969'), Decimal('259848'), Decimal('284743'), Decimal('323142'), Decimal('348242'), Decimal('397036'))]

# %%
# %%sql
# SELECT
#   ROW_NUMBER() OVER (ORDER BY SUM(men_women_2020) DESC) AS ranking,
#   origin_subregion,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   SUM(men_women_1990) AS region_tot_1990,
#   SUM(men_women_1995) AS region_tot_1995,
#   SUM(men_women_2000) AS region_tot_2000,
#   SUM(men_women_2005) AS region_tot_2005,
#   SUM(men_women_2010) AS region_tot_2010,
#   SUM(men_women_2015) AS region_tot_2015,
#   SUM(men_women_2020) AS region_tot_2020
# FROM latam_countries_to_wregions_v
# WHERE
#   destination_region = 'Europe' AND
#   origin_subregion = 'South America'
# GROUP BY
#   origin_subregion,
#   destination_name,
#   destination_subregion,
#   destination_region
# ORDER BY
#   region_tot_2020 DESC
# LIMIT 20;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 20 rows affected.
# [(1, 'South America', 'Spain', 'Southern Europe', 'Europe', Decimal('149497'), Decimal('196014'), Decimal('324757'), Decimal('1473717'), Decimal('2079519'), Decimal('1798182'), Decimal('2232483')),
#  (2, 'South America', 'Italy', 'Southern Europe', 'Europe', Decimal('99552'), Decimal('125602'), Decimal('151648'), Decimal('330054'), Decimal('520935'), Decimal('490932'), Decimal('544875')),
#  (3, 'South America', 'Netherlands', 'Western Europe', 'Europe', Decimal('174549'), Decimal('190749'), Decimal('213430'), Decimal('226937'), Decimal('230770'), Decimal('229844'), Decimal('247320')),
#  (4, 'South America', 'France', 'Western Europe', 'Europe', Decimal('75977'), Decimal('78437'), Decimal('80889'), Decimal('139361'), Decimal('159499'), Decimal('176770'), Decimal('194292')),
#  (5, 'South America', 'Germany', 'Western Europe', 'Europe', Decimal('37353'), Decimal('48985'), Decimal('60611'), Decimal('102898'), Decimal('137322'), Decimal('140942'), Decimal('189154')),
#  (6, 'South America', 'Portugal', 'Southern Europe', 'Europe', Decimal('39330'), Decimal('55550'), Decimal('74035'), Decimal('118189'), Decimal('142723'), Decimal('161800'), Decimal('185609')),
#  (7, 'South America', 'United Kingdom', 'Northern Europe', 'Europe', Decimal('38849'), Decimal('55422'), Decimal('72938'), Decimal('103685'), Decimal('109458'), Decimal('130997'), Decimal('147846')),
#  (8, 'South America', 'Switzerland', 'Western Europe', 'Europe', Decimal('38261'), Decimal('49174'), Decimal('60278'), Decimal('72488'), Decimal('79555'), Decimal('90249'), Decimal('105251')),
#  (9, 'South America', 'Sweden', 'Northern Europe', 'Europe', Decimal('39953'), Decimal('47412'), Decimal('50853'), Decimal('56045'), Decimal('62234'), Decimal('64815'), Decimal('74303')),
#  (10, 'South America', 'Belgium', 'Western Europe', 'Europe', Decimal('15238'), Decimal('16429'), Decimal('17137'), Decimal('23774'), Decimal('31471'), Decimal('41668'), Decimal('50959')),
#  (11, 'South America', 'Norway', 'Northern Europe', 'Europe', Decimal('9058'), Decimal('10490'), Decimal('12164'), Decimal('14719'), Decimal('18736'), Decimal('22801'), Decimal('25246')),
#  (12, 'South America', 'Denmark', 'Northern Europe', 'Europe', Decimal('4417'), Decimal('6071'), Decimal('7720'), Decimal('9628'), Decimal('11032'), Decimal('12764'), Decimal('16421')),
#  (13, 'South America', 'Austria', 'Western Europe', 'Europe', Decimal('7632'), Decimal('8614'), Decimal('9589'), Decimal('10629'), Decimal('11804'), Decimal('13073'), Decimal('16353')),
#  (14, 'South America', 'Ireland', 'Northern Europe', 'Europe', Decimal('554'), Decimal('1824'), Decimal('4098'), Decimal('8206'), Decimal('10962'), Decimal('11199'), Decimal('12816')),
#  (15, 'South America', 'Luxembourg', 'Western Europe', 'Europe', Decimal('529'), Decimal('500'), Decimal('480'), Decimal('414'), Decimal('358'), Decimal('542'), Decimal('6365')),
#  (16, 'South America', 'Finland', 'Northern Europe', 'Europe', Decimal('786'), Decimal('1031'), Decimal('1267'), Decimal('2413'), Decimal('3180'), Decimal('4116'), Decimal('5584')),
#  (17, 'South America', 'Greece', 'Southern Europe', 'Europe', Decimal('4326'), Decimal('4515'), Decimal('4780'), Decimal('5081'), Decimal('5569'), Decimal('5238'), Decimal('5339')),
#  (18, 'South America', 'Hungary', 'Eastern Europe', 'Europe', Decimal('582'), Decimal('928'), Decimal('1271'), Decimal('1563'), Decimal('1865'), Decimal('2965'), Decimal('3768')),
#  (19, 'South America', 'Czechia', 'Eastern Europe', 'Europe', Decimal('197'), Decimal('296'), Decimal('392'), Decimal('784'), Decimal('1099'), Decimal('1630'), Decimal('3113')),
#  (20, 'South America', 'Romania', 'Eastern Europe', 'Europe', Decimal('15'), Decimal('16'), Decimal('19'), Decimal('18'), Decimal('49'), Decimal('228'), Decimal('2679'))]

# %% [markdown]
# This process evolved into creating a table that was later imported into **Microsoft Power BI**, equipped with the necessary attributes for efficient data manipulation. The views **wcountries_to_wcountries_v** and **wcountries_to_wcountries_inter_region_v** were developed specifically to handle interregional migration data, allowing for detailed visualizations of global movement patterns between continents:

# %%
# %%sql
# SELECT
#   c1.id AS origin_id,
#   c1.name AS origin_name,
#   s1.name AS origin_subregion,
#   r1.name AS origin_region,
#   c2.id AS destination_id,
#   c2.name AS destination_name,
#   s2.name AS destination_subregion,
#   r2.name AS destination_region,
#   men_women_1990,
#   men_women_1995,
#   men_women_2000,
#   men_women_2005,
#   men_women_2010,
#   men_women_2015,
#   men_women_2020
# FROM
#   un_migration_stock AS m
#   JOIN un_countries_v AS c1 ON m.origin = c1.id
#   JOIN un_countries_v AS c2 ON m.destination = c2.id
#   JOIN un_subregions AS s1 ON c1.subregion = s1.id
#   JOIN un_subregions AS s2 ON c2.subregion = s2.id
#   JOIN un_regions AS r1 ON s1.region = r1.id
#   JOIN un_regions AS r2 ON s2.region = r2.id
# ORDER BY
#   origin_region,
#   destination_region
# LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 100 rows affected.
# [(694, 'Sierra Leone', 'Western Africa', 'Africa', 624, 'Guinea-Bissau', 'Western Africa', 'Africa', 87, 524, 960, 863, 766, 812, 585),
#  (694, 'Sierra Leone', 'Western Africa', 'Africa', 686, 'Senegal', 'Western Africa', 'Africa', 12313, 12876, 11638, 12523, 14007, 14963, 15453),
#  (694, 'Sierra Leone', 'Western Africa', 'Africa', 710, 'South Africa', 'Southern Africa', 'Africa', 384, 239, 166, 274, 398, 513, 595),
#  (694, 'Sierra Leone', 'Western Africa', 'Africa', 768, 'Togo', 'Western Africa', 'Africa', 49, 55, 62, 70, 93, 105, 105),
#  (204, 'Benin', 'Western Africa', 'Africa', 818, 'Egypt', 'Northern Africa', 'Africa', 46, 35, 27, 32, 35, 24, 35),
#  (204, 'Benin', 'Western Africa', 'Africa', 854, 'Burkina Faso', 'Western Africa', 'Africa', 2054, 2554, 3071, 3540, 3996, 4178, 4342),
#  (270, 'Gambia', 'Western Africa', 'Africa', 132, 'Cabo Verde', 'Western Africa', 'Africa', 7, 10, 12, 9, 5, 5, 4),
#  (270, 'Gambia', 'Western Africa', 'Africa', 288, 'Ghana', 'Western Africa', 'Africa', 19, 19, 21, 30, 1337, 1645, 1888),
#  (270, 'Gambia', 'Western Africa', 'Africa', 324, 'Guinea', 'Western Africa', 'Africa', 811, 935, 654, 457, 319, 281, 268),
#  (270, 'Gambia', 'Western Africa', 'Africa', 384, "Côte d'Ivoire", 'Western Africa', 'Africa', 10359, 6022, 6275, 6569, 6863, 7164, 7437),
#  (270, 'Gambia', 'Western Africa', 'Africa', 430, 'Liberia', 'Western Africa', 'Africa', 656, 650, 630, 504, 711, 816, 630)]

# %% [markdown]
# ⬆️ **wcountries_to_wcountries_v**
#
# ⬇️ **wcountries_to_wcountries_inter_region_v**

# %%
# %%sql
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   men_women_1990,
#   men_women_1995,
#   men_women_2000,
#   men_women_2005,
#   men_women_2010,
#   men_women_2015,
#   men_women_2020
# FROM
#   wcountries_to_wcountries_v
# WHERE
#   origin_region <> destination_region
# ORDER BY
#   origin_subregion, destination_subregion
# LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 100 rows affected.
# [(554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 662, 'Saint Lucia', 'Caribbean', 'Latin America and the Caribbean', 1, 0, 1, 1, 2, 1, 0),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 28, 'Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', 7, 7, 6, 7, 7, 7, 6),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 44, 'Bahamas', 'Caribbean', 'Latin America and the Caribbean', 27, 46, 65, 71, 77, 83, 88),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 52, 'Barbados', 'Caribbean', 'Latin America and the Caribbean', 24, 26, 29, 25, 23, 24, 23),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 92, 'British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', 12, 14, 16, 19, 21, 24, 27),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 136, 'Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', 23, 45, 77, 119, 173, 187, 208),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 212, 'Dominica', 'Caribbean', 'Latin America and the Caribbean', 3, 4, 5, 5, 6, 7, 6),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 214, 'Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', 67, 75, 82, 60, 39, 40, 41),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 662, 'Saint Lucia', 'Caribbean', 'Latin America and the Caribbean', 7, 9, 13, 13, 13, 12, 10),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 28, 'Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', 3, 7, 10, 11, 11, 12, 11),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 44, 'Bahamas', 'Caribbean', 'Latin America and the Caribbean', 14, 16, 19, 21, 22, 24, 24),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 136, 'Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', 17, 33, 58, 53, 53, 57, 63),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 535, 'Bonaire, Sint Eustatius and Saba', 'Caribbean', 'Latin America and the Caribbean', 0, 0, 0, 0, 0, 0, 0),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 222, 'El Salvador', 'Central America', 'Latin America and the Caribbean', 33, 27, 21, 24, 26, 27, 27),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania',

#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 578, 'Norway', 'Northern Europe', 'Europe', 266, 305, 316, 362, 527, 630, 635),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', 125, 140, 155, 186, 296, 373, 389),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 238, 'Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', 7, 9, 10, 14, 38, 42, 51),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 604, 'Peru', 'South America', 'Latin America and the Caribbean', 366, 367, 430, 506, 565, 601, 1120),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 862, 'Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', 131, 129, 127, 133, 141, 148, 137),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', 24, 23, 22, 18, 11, 11, 11),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', 34, 35, 35, 45, 55, 65, 70),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', 0, 0, 0, 0, 272, 320, 346),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', 38, 43, 47, 56, 89, 112, 116),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 238, 'Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', 37, 49, 52, 73, 24, 26, 31),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 604, 'Peru', 'South America', 'Latin America and the Caribbean', 58, 59, 69, 81, 90, 95, 174),
#  (554, 'New Zealand', 'Australia and New Zealand', 'Oceania', 862, 'Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', 16, 15, 15, 15, 17, 18, 16),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', 625, 600, 575, 426, 274, 275, 276),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', 74, 115, 154, 175, 196, 229, 253),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', 297, 372, 447, 519, 585, 689, 747),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 96, 'Brunei Darussalam', 'South-Eastern Asia', 'Asia', 262, 372, 482, 493, 504, 515, 559),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 116, 'Cambodia', 'South-Eastern Asia', 'Asia', 54, 142, 229, 179, 129, 116, 123),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 360, 'Indonesia', 'South-Eastern Asia', 'Asia', 5963, 3945, 1928, 5679, 9796, 10844, 11400),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 418, "Lao People's Democratic Republic", 'South-Eastern Asia', 'Asia', 18, 18, 17, 16, 110, 205, 218),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 458, 'Malaysia', 'South-Eastern Asia', 'Asia', 1851, 2118, 2989, 4005, 4766, 5811, 6157),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 608, 'Philippines', 'South-Eastern Asia', 'Asia', 943, 1269, 2396, 1939, 3932, 3993, 4249),
#  (36, 'Australia', 'Australia and New Zealand', 'Oceania', 626, 'Timor-Leste', 'South-Eastern Asia', 'Asia', 425, 451, 482, 522, 543, 562, 553)]

# %% [markdown]
# By sorting the table **wcountries_to_wcountries_inter_region_v** based on the values of 2020's migration stock, we can delineate the global ranking of inter-regional migration exchanges according to this specific indicator. MySQL's **ranking functions** are used:

# %%
# %%sql
# SELECT
#   ROW_NUMBER() OVER (ORDER BY men_women_2020 DESC) AS ranking,
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   men_women_1990,
#   men_women_1995,
#   men_women_2000,
#   men_women_2005,
#   men_women_2010,
#   men_women_2015,
#   men_women_2020
# FROM
#   wcountries_to_wcountries_v
# WHERE
#   origin_region <> destination_region
# ORDER BY
#   men_women_2020 DESC
# LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 100 rows affected.
# [(1, 484, 'Mexico', 'Central America', 'Latin America and the Caribbean', 840, 'United States of America', 'Northern America', 'Northern America', 4298014, 6827945, 9410529, 10611064, 12168662, 11643298, 10853105),
#  (2, 356, 'India', 'Southern Asia', 'Asia', 840, 'United States of America', 'Northern America', 'Northern America', 450406, 746337, 1048517, 1390605, 1784284, 2389639, 2723764),
#  (3, 398, 'Kazakhstan', 'Central Asia', 'Asia', 643, 'Russian Federation', 'Eastern Europe', 'Europe', 2349697, 2506132, 2571681, 2568446, 2512343, 2560269, 2558907),
#  (4, 643, 'Russian Federation', 'Eastern Europe', 'Europe', 398, 'Kazakhstan', 'Central Asia', 'Asia', 2474111, 2253497, 2032883, 2122379, 2211875, 2352598, 2476018),
#  (5, 156, 'China', 'Eastern Asia', 'Asia', 840, 'United States of America', 'Northern America', 'Northern America', 773939, 1058487, 1348465, 1607654, 1922950, 2676697, 2184110),
#  (6, 608, 'Philippines', 'South-Eastern Asia', 'Asia', 840, 'United States of America', 'Northern America', 'Northern America',
an', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', 24161, 52674, 82440, 116119, 136865, 201014, 217807),
#  (95, 156, 'China', 'Eastern Asia', 'Asia', 826, 'United Kingdom', 'Northern Europe', 'Europe', 23384, 83030, 144073, 146994, 155196, 199428, 208229),
#  (96, 780, 'Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', 840, 'United States of America', 'Northern America', 'Northern America', 115710, 158649, 202410, 217856, 240394, 255967, 208075),
#  (97, 380, 'Italy', 'Southern Europe', 'Europe', 36, 'Australia', 'Australia and New Zealand', 'Oceania', 271095, 260694, 234040, 220513, 204690, 198510, 206282),
#  (98, 566, 'Nigeria', 'Western Africa', 'Africa', 826, 'United Kingdom', 'Northern Europe', 'Europe', 45984, 65168, 85449, 133246, 162051, 181046, 205773),
#  (99, 818, 'Egypt', 'Northern Africa', 'Africa', 840, 'United States of America', 'Northern America', 'Northern America', 66313, 91056, 116275, 124709, 137193, 188170, 204993),
#  (100, 76, 'Brazil', 'South America', 'Latin America and the Caribbean', 392, 'Japan', 'Eastern Asia', 'Asia', 56445, 178865, 254413, 217455, 230552, 173437, 204814)]

# %% [markdown]
# The **wcountries_to_wcountries_inter_region_v** table creation was designed with the necessary attributes for efficient data manipulation within **Power BI**.

# %% [markdown]
# **Migration stock from world countries to Europe**

# %%
# %%sql
# SELECT
#   ROW_NUMBER() OVER (ORDER BY SUM(men_women_2020) DESC) AS ranking,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   SUM(men_women_1990) AS tot_1990,
#   SUM(men_women_1995) AS tot_1995,
#   SUM(men_women_2000) AS tot_2000,
#   SUM(men_women_2005) AS tot_2005,
#   SUM(men_women_2010) AS tot_2010,
#   SUM(men_women_2015) AS tot_2015,
#   SUM(men_women_2020) AS tot_2020
# FROM
#   wcountries_to_wcountries_inter_region_v
# WHERE
#   destination_region = 'Europe'
# GROUP BY
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_name,
#   destination_subregion,
#   destination_region
# ORDER BY
#   tot_2020 DESC
# LIMIT 50;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 50 rows affected.
# [(1, 'Kazakhstan', 'Central Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('2349697'), Decimal('2506132'), Decimal('2571681'), Decimal('2568446'), Decimal('2512343'), Decimal('2560269'), Decimal('2558907')),
#  (2, 'Turkey', 'Western Asia', 'Asia', 'Germany', 'Western Europe', 'Europe', Decimal('1459167'), Decimal('1617880'), Decimal('1604965'), Decimal('1315719'), Decimal('1314223'), Decimal('1343522'), Decimal('1837282')),
#  (3, 'Algeria', 'Northern Africa', 'Africa', 'France', 'Western Europe', 'Europe', Decimal('788914'), Decimal('814417'), Decimal('839920'), Decimal('1337210'), Decimal('1343555'), Decimal('1489151'), Decimal('1637211')),
#  (4, 'Uzbekistan', 'Central Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('890893'), Decimal('918869'), Decimal('913322'), Decimal('1030041'), Decimal('1125335'), Decimal('1146803'), Decimal('1146175')),
#  (5, 'Kazakhstan', 'Central Asia', 'Asia', 'Germany', 'Western Europe', 'Europe', Decimal('10199'), Decimal('248645'), Decimal('487090'), Decimal('671031'), Decimal('812460'), Decimal('832107'), Decimal('1128201')),
#  (6, 'Morocco', 'Northern Africa', 'Africa', 'France', 'Western Europe', 'Europe', Decimal('713987'), Decimal('737068'), Decimal('760148'), Decimal('832641'), Decimal('870001'), Decimal('964250'), Decimal('1059918')),
#  (7, 'India', 'Southern Asia', 'Asia', 'United Kingdom', 'Northern Europe', 'Europe', Decimal('399526'), Decimal('422284'), Decimal('452144'), Decimal('548130'), Decimal('684136'), Decimal('807790'), Decimal('835359')),
#  (8, 'Morocco', 'Northern Africa', 'Africa', 'Spain', 'Southern Europe', 'Europe', Decimal('133341'), Decimal('165214'), Decimal('266706'), Decimal('521940'), Decimal('763734'), Decimal('699880'), Decimal('785884')),
#  (9, 'Azerbaijan', 'Western Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('936852'), Decimal('905728'), Decimal('841759'), Decimal('805658'), Decimal('752975'), Decimal('767339'), Decimal('766918')),
#  (10, 'Syrian Arab Republic', 'Western Asia', 'Asia', 'Germany', 'Western Europe', 'Europe', Decimal('15330'), Decimal('20223'), Decimal('25116'), Decimal('34895'), Decimal('42766'), Decimal('197186'), Decimal('707457')),
#  (11, 'Kyrgyzstan', 'Central Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('433625'), Decimal('455644'), Decimal('461140'), Decimal('526124'), Decimal('580279'), Decimal('591349'), Decimal('591025')),
#  (12, 'Pakistan', 'Southern Asia', 'Asia', 'United Kingdom', 'Northern Europe', 'Europe', Decimal('228321'), Decimal('267177'), Decimal('310526'), Decimal('379494'), Decimal('460473'), Decimal('532502'), Decimal('537047')),
#  (13, 'Armenia', 'Western Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('535266'), Decimal('516425'), Decimal('478856'), Decimal('503316'), Decimal('517417'), Decimal('527287'), Decimal('526997')),
#  (14, 'Tajikistan', 'Central Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('424727'), Decimal('410349'), Decimal('381090'), Decimal('423794'), Decimal('457775'), Decimal('466508'), Decimal('466252')),
#  (15, 'Morocco', 'Northern Africa', 'Africa', 'Italy', 'Southern Europe', 'Europe', Decimal('169285'), Decimal('227427'), Decimal('285569'), Decimal('355367'), Decimal('416832'), Decimal('422481'), Decimal('451960')),
#  (16, 'Colombia', 'South America', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('12548'), Decimal('21683'), Decimal('40145'), Decimal('270028'), Decimal('376161'), Decimal('347505'), Decimal('450377')),
#  (17, 'Georgia', 'Western Asia', 'Asia', 'Russian Federation', 'Eastern Europe', 'Europe', Decimal('656888'), Decimal('653159'), Decimal('625743'), Decimal('539318'), Decimal('441793'), Decimal('450221'), Decimal('449973')),
#  (18, 'Tunisia', 'Northern Africa', 'Africa', 'France', 'Western Europe', 'Europe', Decimal('276216'), Decimal('285233'), Decimal('294250'), Decimal('362087'), Decimal('364914'), Decimal('404445'), Decimal('444572')),
#  (19, 'Ecuador', 'South America', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('3734'), Decimal('11606'), Decimal('24472'), Decimal('456379'), Decimal('496666'), Decimal('416394'), Decimal('430275')),
#  (20, 'Turkey', 'Western Asia', 'Asia', 'France', 'Western Europe', 'Europe', Decimal('241148'), Decimal('248944'), Decimal('256739'), Decimal('229714'), Decimal('279301'), Decimal('309559'), Decimal('340271')),
#  (21, 'Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('32469'), Decimal('38704'), Decimal('61587'), Decimal('108707'), Decimal('148147'), Decimal('160478'), Decimal('325667')),
#  (22, 'Argentina', 'South America', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('42923'), Decimal('50810'), Decimal('79339'), Decimal('244014'), Decimal('282553'), Decimal('251841'), Decimal('284921')),
#  (23, 'Afghanistan', 'Southern Asia', 'Asia', 'Germany', 'Western Europe', 'Europe', Decimal('33279'), Decimal('51537'), Decimal('69794'), Decimal('75824'), Decimal('80248'), Decimal('82361'), Decimal('250444')),
#  (24, 'South Africa', 'Southern Africa', 'Africa', 'United Kingdom', 'Northern Europe', 'Europe', Decimal
 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('15160'), Decimal('21654'), Decimal('36953'), Decimal('73049'), Decimal('136976'), Decimal('156905'), Decimal('184832')),
#  (38, 'Suriname', 'South America', 'Latin America and the Caribbean', 'Netherlands', 'Western Europe', 'Europe', Decimal('156211'), Decimal('167083'), Decimal('183613'), Decimal('188714'), Decimal('186216'), Decimal('179040'), Decimal('182922')),
#  (39, 'Angola', 'Middle Africa', 'Africa', 'Portugal', 'Southern Europe', 'Europe', Decimal('141573'), Decimal('154254'), Decimal('173193'), Decimal('169591'), Decimal('137826'), Decimal('156251'), Decimal('179524')),
#  (40, 'China', 'Eastern Asia', 'Asia', 'Spain', 'Southern Europe', 'Europe', Decimal('8432'), Decimal('4349'), Decimal('2138'), Decimal('81322'), Decimal('154918'), Decimal('155713'), Decimal('179104')),
#  (41, 'Morocco', 'Northern Africa', 'Africa', 'Netherlands', 'Western Europe', 'Europe', Decimal('114850'), Decimal('130895'), Decimal('151473'), Decimal('167369'), Decimal('166946'), Decimal('166873'), Decimal('174914')),
#  (42, 'United States of America', 'Northern America', 'Northern America', 'United Kingdom', 'Northern Europe', 'Europe', Decimal('141818'), Decimal('146271'), Decimal('153185'), Decimal('163855'), Decimal('188055'), Decimal('189961'), Decimal('170771')),
#  (43, 'Zimbabwe', 'Eastern Africa', 'Africa', 'United Kingdom', 'Northern Europe', 'Europe', Decimal('20857'), Decimal('34085'), Decimal('47888'), Decimal('79684'), Decimal('126091'), Decimal('150915'), Decimal('170350')),
#  (44, 'India', 'Southern Asia', 'Asia', 'Italy', 'Southern Europe', 'Europe', Decimal('3413'), Decimal('23261'), Decimal('43109'), Decimal('89745'), Decimal('128999'), Decimal('138591'), Decimal('167272')),
#  (45, 'Cuba', 'Caribbean', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('21854'), Decimal('28314'), Decimal('45738'), Decimal('71614'), Decimal('103189'), Decimal('131134'), Decimal('162368')),
#  (46, 'Turkey', 'Western Asia', 'Asia', 'Austria', 'Western Europe', 'Europe', Decimal('88108'), Decimal('99359'), Decimal('110695'), Decimal('133248'), Decimal('157450'), Decimal('153899'), Decimal('159999')),
#  (47, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', 'Spain', 'Southern Europe', 'Europe', Decimal('1806'), Decimal('2467'), Decimal('4190'), Decimal('92918'), Decimal('216020'), Decimal('150680'), Decimal('159936')),
#  (48, 'Brazil', 'South America', 'Latin America and the Caribbean', 'Portugal', 'Southern Europe', 'Europe', Decimal('23722'), Decimal('35931'), Decimal('49599'), Decimal('91614'), Decimal('118415'), Decimal('134245'), Decimal('154017')),
#  (49, 'United States of America', 'Northern America', 'Northern America', 'Germany', 'Western Europe', 'Europe', Decimal('99835'), Decimal('104837'), Decimal('109838'), Decimal('110843'), Decimal('110802'), Decimal('113721'), Decimal('152639')),
#  (50, 'Iran (Islamic Republic of)', 'Southern Asia', 'Asia', 'Germany', 'Western Europe', 'Europe', Decimal('95723'), Decimal('100027'), Decimal('104331'), Decimal('108310'), Decimal('110767'), Decimal('113685'), Decimal('152590'))]

# %% [markdown]
# The ranking highlights that migration flows from Africa and Asia to Europe are particularly dominant, reflecting significant migration stocks from these regions. Notably, **Colombia** emerges as the first country of origin from the Americas with a substantial migration stock to **Spain**, positioned at number 16 in the ranking.

# %% [markdown]
# During the process, it was necessary to unpivot the table **wcountries_to_wcountries_inter_region_unpivoted_v**, resulting in a new unpivoted table. This transformation allowed for the calculation of new indicators based on migration stock values and provided a more coherent structure aligned with a normalized approach. Additionally, this structure is crucial when considering the table’s import into Power BI for further analysis.

# %% [raw]
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '1990' AS year,
#   men_women_1990 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '1995' AS year,
#   men_women_1995 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '2000' AS year,
#   men_women_2000 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '2005' AS year,
#   men_women_2005 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '2010' AS year,
#   men_women_2010 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '2015' AS year,
#   men_women_2015 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v
#
# UNION ALL
#
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   '2020' AS year,
#   men_women_2020 AS migration_stock
# FROM
#   wcountries_to_wcountries_inter_region_v;

# %% [markdown]
# ⬇️ **wcountries_to_wcountries_inter_region_unpivoted_v**

# %%
# %%sql
# SELECT * FROM wcountries_to_wcountries_inter_region_unpivoted_v LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 100 rows affected.
# [(4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1990', 20),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1995', 20),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2000', 20),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2005', 16),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2010', 9),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2015', 9),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2020', 9),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1990', 2729),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1995', 7893),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2000', 12580),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2005', 18617),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2010', 30840),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2015', 49550),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2020', 60879),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1990', 4748),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1995', 5357),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2000', 5966),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2005', 6614),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2010', 10055),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2015', 41725),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2020', 47602),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1990', 140),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1995', 216),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2000', 292),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2005', 281),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2010', 270),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2015', 282),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2020', 277),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1990', 93),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1995', 79),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2000', 60),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2005', 2479),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2010', 4242),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2015', 12819),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2020', 24670),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1990', 2),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1995', 1),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2000', 0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2005', 1),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2010', 1),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2015', 2),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2020', 1),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1990', 0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1995', 0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2000', 0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2005', 28),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2010', 58),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2015', 68),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2020', 73),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '1990', 222),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '1995', 223),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '2000', 223),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '2005', 2320),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '2010', 2450),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '2015', 3438),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '2020', 426),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '1990', 5321),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '1995', 13677),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '2000', 22359),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '2005', 30718),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '2010', 40945),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '2015', 51641),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 124, 'Canada', 'Northern America', 'Northern America', '2020', 55954),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '1990', 25),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '1995', 11),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '2000', 3),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '2005', 3),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '2010', 5),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '2015', 4),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 188, 'Costa Rica', 'Central America', 'Latin America and the Caribbean', '2020', 4),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '1990', 51),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '1995', 77),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '2000', 103),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '2005', 221),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '2010', 317),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '2015', 418),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 203, 'Czechia', 'Eastern Europe', 'Europe', '2020', 484),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '1990', 354),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '1995', 1648),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '2000', 2941),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '2005', 6609),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '2010', 9817),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '2015', 12293),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 208, 'Denmark', 'Northern Europe', 'Europe', '2020', 13715),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '1990', 18),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '1995', 21),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '2000', 23),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '2005', 28),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '2010', 44),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '2015', 112),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 218, 'Ecuador', 'South America', 'Latin America and the Caribbean', '2020', 167),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '1990', 237),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '1995', 188),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '2000', 154),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '2005', 183),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '2010', 198),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '2015', 135),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 818, 'Egypt', 'Northern Africa', 'Africa', '2020', 210),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 233, 'Estonia', 'Northern Europe', 'Europe', '1990', 0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 233, 'Estonia', 'Northern Europe', 'Europe', '1995', 0)]

# %% [markdown]
# To enhance data visualization, a need to compute new indicators for **migration_stock** data arose, specifically the **growth rate** and **logarithmic scale**. These calculations were applied to the unpivoted table **wcountries_to_wcountries_inter_region_unpivoted_v** to facilitate a more comprehensive analysis of migration trends:

# %%
# %%sql
# SELECT
#   origin_id,
#   origin_name,
#   origin_subregion,
#   origin_region,
#   destination_id,
#   destination_name,
#   destination_subregion,
#   destination_region,
#   year,
#   migration_stock,
#   (
#       (migration_stock - LAG(migration_stock, 1) OVER (PARTITION BY origin_name, destination_name ORDER BY year)) /
#       NULLIF(LAG(migration_stock, 1) OVER (PARTITION BY origin_name, destination_name ORDER BY year), 0)
#       * 100
#   ) AS mig_stock_growth_rate,
#   LOG(migration_stock) AS mig_stock_log
# FROM
#   wcountries_to_wcountries_inter_region_unpivoted_v
# LIMIT 50;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 50 rows affected.
# [(4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1990', 20, None, 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1995', 20, Decimal('0.0000'), 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2000', 20, Decimal('0.0000'), 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2005', 16, Decimal('-20.0000'), 2.772588722239781),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2010', 9, Decimal('-43.7500'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2015', 9, Decimal('0.0000'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2020', 9, Decimal('0.0000'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1990', 2729, None, 7.911690520708339),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1995', 7893, Decimal('189.2268'), 8.973731569708402),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2000', 12580, Decimal('59.3817'), 9.439863530254431),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2005', 18617, Decimal('47.9889'), 9.831830420771897),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2010', 30840, Decimal('65.6550'), 10.336567827677266),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2015', 49550, Decimal('60.6680'), 10.810737539758135),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2020', 60879, Decimal('22.8638'), 11.016643566645078),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1990', 4748, None, 8.465478755729558),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1995', 5357, Decimal('12.8265'), 8.58615939588096),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2000', 5966, Decimal('11.3683'), 8.693831965074693),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2005', 6614, Decimal('10.8615'), 8.796943893541737),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2010', 10055, Decimal('52.0260'), 9.215825302206753),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2015', 41725, Decimal('314.9677'), 10.638855748530036),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2020', 47602, Decimal('14.0851'), 10.770630056143553),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1990', 140, None, 4.941642422609304),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1995', 216, Decimal('54.2857'), 5.375278407684165),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2000', 292, Decimal('35.1852'), 5.676753802268282),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2005', 281, Decimal('-3.7671'), 5.638354669333745),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2010', 270, Decimal('-3.9146'), 5.598421958998375),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2015', 282, Decimal('4.4444'), 5.641907070938114),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2020', 277, Decimal('-1.7730'), 5.6240175061873385),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1990', 93, None, 4.532599493153256),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1995', 79, Decimal('-15.0538'), 4.3694478524670215),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2000', 60, Decimal('-24.0506'), 4.0943445622221),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2005', 2479, Decimal('4031.6667'), 7.8156105320351905),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2010', 4242, Decimal('71.1174'), 8.352790135124629),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2015', 12819, Decimal('202.1924'), 9.458683724312134),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2020', 24670, Decimal('92.4487'), 10.113343209523402),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1990', 2, None, 0.6931471805599453),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1995', 1, Decimal('-50.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2000', 0, Decimal('-100.0000'), None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2005', 1, None, 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2010', 1, Decimal('0.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2015', 2, Decimal('100.0000'), 0.6931471805599453),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2020', 1, Decimal('-50.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1990', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1995', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2000', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2005', 28, None, 3.332204510175204),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2010', 58, Decimal('107.1429'), 4.060443010546419),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2015', 68, Decimal('17.2414'), 4.219507705176107),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2020', 73, Decimal('7.3529'), 4.290459441148391),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '1990', 222, None, 5.402677381872279)]

# %% [markdown]
# Given that there is no prior data available for the year 1990 to calculate the growth rate, we opted to use the **first available value in the series** (the growth rate from 1995) as a standard reference for all cases. This approach ensures continuity in the dataset and allows for meaningful comparisons across the years, despite the lack of earlier data points. A new view was created in order to import it in **Power BI**:

# %% [raw]
# WITH mig_stock_agg AS (
#     SELECT
#         origin_region,
#         origin_subregion,
#         origin_name,
#         destination_region,
#         destination_subregion,
#         destination_name,
#         year,
#         SUM(migration_stock) AS region_mig_stock
#     FROM
#         wcountries_to_wcountries_inter_region_unpivoted_v
#     GROUP BY
#         origin_region,
#         origin_subregion,
#         origin_name,
#         destination_region,
#         destination_subregion,
#         destination_name,
#         year
# ),
#
# mig_stock_agg_ext AS (
#     SELECT
#         origin_region,
#         origin_subregion,
#         origin_name,
#         destination_region,
#         destination_subregion,
#         destination_name,
#         year,
#         region_mig_stock,
#         (
#             (region_mig_stock - LAG(region_mig_stock, 1) OVER (PARTITION BY origin_region, origin_subregion, origin_name, destination_region, destination_subregion, destination_name ORDER BY year)) /
#             NULLIF(LAG(region_mig_stock, 1) OVER (PARTITION BY origin_region, origin_subregion, origin_name, destination_region, destination_subregion, destination_name ORDER BY year), 0)
#             * 100
#         ) AS region_mig_stock_growth_rate,
#         LOG(region_mig_stock) AS region_mig_stock_log
#     FROM
#         mig_stock_agg
# ),
#
# first_growth_rate AS (
#     SELECT
#         origin_region,
#         origin_subregion,
#         origin_name,
#         destination_region,
#         destination_subregion,
#         destination_name,
#         region_mig_stock_growth_rate AS region_growth_rate_1995
#     FROM
#         mig_stock_agg_ext
#     WHERE
#         year = 1995
# )
#
# SELECT
#     i.origin_region,
#     i.origin_subregion,
#     i.origin_name,
#     i.destination_region,
#     i.destination_subregion,
#     i.destination_name,
#     i.year,
#     i.region_mig_stock,
#     CASE
#         WHEN i.year = 1990 THEN fg.region_growth_rate_1995
#         ELSE i.region_mig_stock_growth_rate
#     END AS region_mig_stock_growth_rate,
#     i.region_mig_stock_log
# FROM
#     mig_stock_agg_ext AS i
# LEFT JOIN
#     first_growth_rate AS fg
# ON
#     i.origin_region = fg.origin_region
#     AND i.origin_subregion = fg.origin_subregion
#     AND i.origin_name = fg.origin_name
#     AND i.destination_region = fg.destination_region
#     AND i.destination_subregion = fg.destination_subregion
#     AND i.destination_name = fg.destination_name
# ORDER BY
#     i.origin_region, i.origin_subregion, i.origin_name, i.destination_region, i.destination_subregion, i.destination_name, i.year;

# %%
# %%sql
# SELECT * FROM wcountries_to_wcountries_inter_region_unpivoted_ext_v LIMIT 50;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dap1
# 50 rows affected.
# [(4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1990', 20, Decimal('0.0000'), 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '1995', 20, Decimal('0.0000'), 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2000', 20, Decimal('0.0000'), 2.995732273553991),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2005', 16, Decimal('-20.0000'), 2.772588722239781),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2010', 9, Decimal('-43.7500'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2015', 9, Decimal('0.0000'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 32, 'Argentina', 'South America', 'Latin America and the Caribbean', '2020', 9, Decimal('0.0000'), 2.1972245773362196),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1990', 2729, Decimal('189.2268'), 7.911690520708339),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '1995', 7893, Decimal('189.2268'), 8.973731569708402),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2000', 12580, Decimal('59.3817'), 9.439863530254431),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2005', 18617, Decimal('47.9889'), 9.831830420771897),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2010', 30840, Decimal('65.6550'), 10.336567827677266),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2015', 49550, Decimal('60.6680'), 10.810737539758135),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 36, 'Australia', 'Australia and New Zealand', 'Oceania', '2020', 60879, Decimal('22.8638'), 11.016643566645078),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1990', 4748, Decimal('12.8265'), 8.465478755729558),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '1995', 5357, Decimal('12.8265'), 8.58615939588096),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2000', 5966, Decimal('11.3683'), 8.693831965074693),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2005', 6614, Decimal('10.8615'), 8.796943893541737),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2010', 10055, Decimal('52.0260'), 9.215825302206753),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2015', 41725, Decimal('314.9677'), 10.638855748530036),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 40, 'Austria', 'Western Europe', 'Europe', '2020', 47602, Decimal('14.0851'), 10.770630056143553),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1990', 140, Decimal('54.2857'), 4.941642422609304),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '1995', 216, Decimal('54.2857'), 5.375278407684165),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2000', 292, Decimal('35.1852'), 5.676753802268282),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2005', 281, Decimal('-3.7671'), 5.638354669333745),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2010', 270, Decimal('-3.9146'), 5.598421958998375),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2015', 282, Decimal('4.4444'), 5.641907070938114),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 112, 'Belarus', 'Eastern Europe', 'Europe', '2020', 277, Decimal('-1.7730'), 5.6240175061873385),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1990', 93, Decimal('-15.0538'), 4.532599493153256),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '1995', 79, Decimal('-15.0538'), 4.3694478524670215),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2000', 60, Decimal('-24.0506'), 4.0943445622221),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2005', 2479, Decimal('4031.6667'), 7.8156105320351905),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2010', 4242, Decimal('71.1174'), 8.352790135124629),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2015', 12819, Decimal('202.1924'), 9.458683724312134),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 56, 'Belgium', 'Western Europe', 'Europe', '2020', 24670, Decimal('92.4487'), 10.113343209523402),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1990', 2, Decimal('-50.0000'), 0.6931471805599453),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '1995', 1, Decimal('-50.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2000', 0, Decimal('-100.0000'), None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2005', 1, None, 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2010', 1, Decimal('0.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2015', 2, Decimal('100.0000'), 0.6931471805599453),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 68, 'Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', '2020', 1, Decimal('-50.0000'), 0.0),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1990', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '1995', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2000', 0, None, None),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2005', 28, None, 3.332204510175204),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2010', 58, Decimal('107.1429'), 4.060443010546419),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2015', 68, Decimal('17.2414'), 4.219507705176107),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 76, 'Brazil', 'South America', 'Latin America and the Caribbean', '2020', 73, Decimal('7.3529'), 4.290459441148391),
#  (4, 'Afghanistan', 'Southern Asia', 'Asia', 100, 'Bulgaria', 'Eastern Europe', 'Europe', '1990', 222, Decimal('0.4505'), 5.402677381872279)]

# %% [markdown]
# ⬆️ **wcountries_to_wcountries_inter_region_unpivoted_ext_v**
